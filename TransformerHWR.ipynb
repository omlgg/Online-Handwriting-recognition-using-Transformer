# %%
# !git clone https://github.com/omlgg/Online-Handwriting-recognition-using-Transformer.git
# Out:
# Cloning into 'Online-Handwriting-recognition-using-Transformer'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 28 (delta 2), reused 6 (delta 1), pack-reused 18 (from 1)
# Receiving objects: 100% (28/28), 69.41 MiB | 15.63 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Updating files: 100% (13/13), done.

# %%
# %cd Online-Handwriting-recognition-using-Transformer
# Out:
# /content/Online-Handwriting-recognition-using-Transformer

# %% [markdown]
# # Preprocess Data

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
import os
import numpy as np
from preprocessing import *
from features_extraction import *

from glob import glob

# %%
# extract strokes (x and y cordinate) from xml file and return a list of strokes as ink object [mark pen up with 1]
def extract_strokes(sample):
  tree = ET.parse(sample)
  r = tree.getroot()
  stroke_set = r.find("StrokeSet")
  strokes = []
  for stroke_node in stroke_set:
      for point in stroke_node:
          x = int(point.attrib['x'])
          y = int(point.attrib['y'])
          time = float(point.attrib['time'])
          strokes.append([x,y,0])
      strokes[-1][-1] = 1 # pen-up
  return strokes

# %%
#  extract handwriting from the raw data
# %cd data
# !tar -xf "ascii-all.tar.gz"
# !tar -xf "lineStrokes-all.tar.gz"
# %cd ..
# Out:
# /content/Online-Handwriting-recognition-using-Transformer/data
# /content/Online-Handwriting-recognition-using-Transformer

# %%
PATH= 'data/lineStrokes'
xml_files = [y for x in os.walk(PATH) for y in glob(os.path.join(x[0], '*.xml'))]
PATH= 'data/ascii'
txt_files = [y for x in os.walk(PATH) for y in glob(os.path.join(x[0], '*.txt'))]

# %%
#  Clean up the text and format it to be ready for preprocessing
data=[]
for txt_file in txt_files:
  with open(txt_file) as f:
    lines = f.readlines()
    try:
      indx = lines.index('CSR:\n')
    except:
      # print(lines)
      # print(txt_file)
      indx = lines.index('CSR: \n')
      # break
    lines = lines[indx+2:]
    for i,line in enumerate(lines):
      xml_file = txt_file.replace('ascii','lineStrokes').replace('.txt','')
      xml_file = xml_file + f'-{i+1:02}.xml'
      data.append({'file_path':xml_file,'transcript':line.replace('\n','')})
print(data)
# Out:
# [{'file_path': 'data/lineStrokes/g06/g06-183/g06-183z-01.xml', 'transcript': 'This happy but impermanent State'}, {'file_path': 'data/lineStrokes/g06/g06-183/g06-183z-02.xml', 'transcript': 'of affairs was brought about by a'}, {'file_path': 'data/lineStrokes/g06/g06-183/g06-183z-03.xml', 'transcript': 'very careful application of the'}, {'file_path': 'data/lineStrokes/g06/g06-183/g06-183z-04.xml', 'transcript': 'homoeopathic system. At that'}, {'file_path': 'data/lineStrokes/g06/g06-183/g06-183z-05.xml', 'transcript': 'date the doctrine that "likes'}, {'file_path': 'data/lineStrokes/g06/g06-183/g06-183z-06.xml', 'transcript': 'should be treated by likes",'}, {'file_path': 'data/lineStrokes/g06/g06-183/g06-183z-07.xml', 'transcript': 'which is its essence, was completely'}, {'file_path': 'data/lineStrokes/g06/g06-183/g06-183z-08.xml', 'transcript': 'revolutionary.'}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-01.xml', 'transcript': 'My father hung upon every word,'}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-02.xml', 'transcript': 'but could get nothing from him.'}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-03.xml', 'transcript': "When he saw Trelawny's printed"}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-04.xml', 'transcript': 'letter, Lord Sidney wrote to Douglas'}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-05.xml', 'transcript': 'Kinnaird saying that it was'}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-06.xml', 'transcript': 'incorrect throughout. His only'}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-07.xml', 'transcript': 'reference to Trelawny by name in the'}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-08.xml', 'transcript': 'course of several communications to'}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-09.xml', 'transcript': "Hobhouse and Kinnaird about Byron's"}, {'file_path': 'data/lineStrokes/g06/g06-199/g06-199z-10.xml', 'transcript': 'affairs is satirical:'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000a-01.xml', 'transcript': 'In mid-April Anglesey moved his family and'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000a-02.xml', 'transcript': 'entourage from Rome to Naples , there to await'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000a-03.xml', 'transcript': 'the arrival of his yacht from England . The'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000a-04.xml', 'transcript': 'beauty of the place quite exceeded his '}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000a-05.xml', 'transcript': "expectations . 'I am enchanted' , he told Arthur "}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000a-06.xml', 'transcript': "Paget . 'Probably"}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000d-01.xml', 'transcript': 'In mid-April Anglesey moved his family and entourage '}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000d-02.xml', 'transcript': 'from Rome to Naples , there to await the arrival of '}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000d-03.xml', 'transcript': 'his yacht from England . The beauty of the place '}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000d-04.xml', 'transcript': "quite exceeded his expectations . 'I am enchanted' , he told "}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000d-05.xml', 'transcript': "Arthur Paget . 'Probably the Element [the water] has not"}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000f-01.xml', 'transcript': 'In mid-April Anglesey'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000f-02.xml', 'transcript': 'moved his family and'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000f-03.xml', 'transcript': 'entourage from Rome to Naples ,'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000f-04.xml', 'transcript': 'there to await the arrival of'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000f-05.xml', 'transcript': 'his yacht from England . The'}, {'file_path': 'data/lineStrokes/g06/g06-000/g06-000f-06.xml', 'tra ...

# %%
#  Convert the list to dataframe to easily process the data
df = pd.DataFrame(data)
df['exists'] = df['file_path'].apply(lambda x :os.path.exists(x))

# %%
df['exists'].value_counts()
# Out:
# exists
# True     12187
# False     1021
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                       file_path  \
# 0  data/lineStrokes/g06/g06-183/g06-183z-01.xml
# 1  data/lineStrokes/g06/g06-183/g06-183z-02.xml
# 2  data/lineStrokes/g06/g06-183/g06-183z-03.xml
# 3  data/lineStrokes/g06/g06-183/g06-183z-04.xml
# 4  data/lineStrokes/g06/g06-183/g06-183z-05.xml
#
#                           transcript  exists
# 0   This happy but impermanent State    True
# 1  of affairs was brought about by a    True
# 2    very careful application of the    True
# 3       homoeopathic system. At that    True
# 4      date the doctrine that "likes    True

# %%
# Keep only the files that exist
data =df[df['exists']]

# Filter for testing
data = data.head(256)

# %%
#  name the preprocessing methods and features extraction
NORM_ARGS = ["origin","smooth", "slope", "resample", "slant", "height"]
FEAT_ARGS = ["x_cor","y_cor","penup","dir", "curv", "vic_aspect", "vic_curl", "vic_line", "vic_slope", "bitmap"]

# %%
#  iterate over the data, preporcess and extract the features, then save the data to binary file
# !mkdir data/bin_files
from tqdm import tqdm
for i,sample in tqdm(data.iterrows()):
  strokes = extract_strokes(sample['file_path'])
  strokes = np. array(strokes)
  ink = preprocess_handwriting(strokes, NORM_ARGS)
  feat = calculate_feature_vector_sequence(ink, FEAT_ARGS)
  outfilename = sample['file_path'].split('/')[-1].replace('.xml','.bin')
  outfilename= 'data/bin_files/'+ outfilename
  feat.tofile(outfilename)
# Out:
# 256it [01:51,  2.31it/s]

# %%
data.head()
# Out:
#                                       file_path  \
# 0  data/lineStrokes/g06/g06-183/g06-183z-01.xml
# 1  data/lineStrokes/g06/g06-183/g06-183z-02.xml
# 2  data/lineStrokes/g06/g06-183/g06-183z-03.xml
# 3  data/lineStrokes/g06/g06-183/g06-183z-04.xml
# 4  data/lineStrokes/g06/g06-183/g06-183z-05.xml
#
#                           transcript  exists
# 0   This happy but impermanent State    True
# 1  of affairs was brought about by a    True
# 2    very careful application of the    True
# 3       homoeopathic system. At that    True
# 4      date the doctrine that "likes    True

# %% [markdown]
# # Train model

# %%
import os
import random
from glob import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
from model import Transformer
from utils import VectorizeChar, DisplayOutputs, CustomSchedule, path_to_features , wer, cer
import pandas as pd

# %%
def set_seeds(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

set_seeds()

# %%
# to tokenize the text
vectorizer = VectorizeChar(100)

# %%
max_target_len = 100  # all transcripts in out data are < 100 characters
print("vocab size", len(vectorizer.get_vocabulary()))
# Out:
# vocab size 95

# %%
#  utilities for data preparation for training and testing [Convert to TF Dataset]
def encode(path,txt):
  """Encode a text into a sequence of vectors."""
  txt = txt.numpy().decode('utf8')
  y = tf.convert_to_tensor(vectorizer(txt),dtype=tf.int64)
  x = path_to_features(path)
  return x,y
def tf_encode(path,txt):
  """ util py function to be used with tensors."""
  x,y = tf.py_function(encode, [path,txt], [tf.float32,tf.int64])
  return x,y
def create_tf_dataset(data, batch_size=4):
  """Create a tf.data.Dataset from the given data."""
  dataset = tf.data.Dataset.from_tensor_slices((np.array(data["filename"].values),np.array(data["transcript"].values)))
  dataset = dataset.map(tf_encode, num_parallel_calls=tf.data.experimental.AUTOTUNE)
  dataset = dataset.padded_batch(batch_size, padded_shapes=([None,20], [None]))
  dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
  dataset = dataset.map(lambda x, y: {"source": x, "target": y})
  return dataset

# %% [markdown]
# ## Create and train end to end model

# %%
#df = pd.read_excel('data/iam.xlsx')
#df['filename'] = df['file_path'].apply(lambda x: "data/content/bin_files/"+x.split('/')[-1].replace('.xml','.bin'))
#print(df)

# Testing
df = data.copy()
df['filename'] = df['file_path'].apply(lambda x: "data/bin_files/"+x.split('/')[-1].replace('.xml','.bin'))
print(df)

# split data into train and test
msk = np.random.rand(len(df)) < 0.95
train_data = df[msk]
dev_data = df[~msk]
# create tf dataset for training and validation
ds = create_tf_dataset(train_data, batch_size=32)
val_ds = create_tf_dataset(dev_data, batch_size=8)
# Out:
#                                         file_path  \
# 0    data/lineStrokes/g06/g06-183/g06-183z-01.xml
# 1    data/lineStrokes/g06/g06-183/g06-183z-02.xml
# 2    data/lineStrokes/g06/g06-183/g06-183z-03.xml
# 3    data/lineStrokes/g06/g06-183/g06-183z-04.xml
# 4    data/lineStrokes/g06/g06-183/g06-183z-05.xml
# ..                                            ...
# 313  data/lineStrokes/b04/b04-363/b04-363z-01.xml
# 314  data/lineStrokes/b04/b04-363/b04-363z-02.xml
# 315  data/lineStrokes/b04/b04-363/b04-363z-03.xml
# 316  data/lineStrokes/b04/b04-363/b04-363z-04.xml
# 317  data/lineStrokes/b04/b04-363/b04-363z-05.xml
#
#                             transcript  exists                        filename
# 0     This happy but impermanent State    True  data/bin_files/g06-183z-01.bin
# 1    of affairs was brought about by a    True  data/bin_files/g06-183z-02.bin
# 2      very careful application of the    True  data/bin_files/g06-183z-03.bin
# 3         homoeopathic system. At that    True  data/bin_files/g06-183z-04.bin
# 4        date the doctrine that "likes    True  data/bin_files/g06-183z-05.bin
# ..                                 ...     ...                             ...
# 313                    Understood! The    True  data/bin_files/b04-363z-01.bin
# 314             Danes are annoyed with    True  data/bin_files/b04-363z-02.bin
# 315       British farmers for fighting    True  data/bin_files/b04-363z-03.bin
# 316        against Danish competition.    True  data/bin_files/b04-363z-04.bin
# 317          They say that our farmers    True  data/bin_files/b04-363z-05.bin
#
# [256 rows x 4 columns]

# %%
len(train_data),len(dev_data)
# Out:
# (238, 18)

# %%
# to display the output of the model after each epoch for the first batch of the validation set
batch = next(iter(val_ds))
# The vocabulary to convert predicted indices into characters
idx_to_char = vectorizer.get_vocabulary()
display_cb = DisplayOutputs(
    batch, idx_to_char, target_start_token_idx=2, target_end_token_idx=3
)  # set the arguments as per vocabulary index for '<' and '>'

# create the model and compile it
model = Transformer(
    num_hid=100,
    num_head=2,
    num_feed_forward=256,
    target_maxlen=max_target_len,
    num_layers_enc=4,
    num_layers_dec=1,
    num_classes=95,
)
loss_fn = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, label_smoothing=0.1,
)

learning_rate = CustomSchedule(
    init_lr=0.00001,
    lr_after_warmup=0.001,
    final_lr=0.00001,
    warmup_epochs=15,
    decay_epochs=85,
    steps_per_epoch=len(ds),
)
optimizer = keras.optimizers.Adam(learning_rate)
# optimizer = keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss=loss_fn)

# %%
model.summary()
# Out:
# Model: "transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Conv2dSubsampling                    │ ?                           │     0 (unbuilt) │
# │ (Conv2dSubsampling)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ token_embedding (TokenEmbedding)     │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_4 (Sequential)            │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_decoder                  │ ?                           │     0 (unbuilt) │
# │ (TransformerDecoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
import keras
import tensorflow as tf

# Use GPU
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18173072750026274980
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14626652160
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 784452693517377072
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
#  train the model
print(ds)
print(val_ds)
#ds = tf.convert_to_tensor(ds)
history = model.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=20)
# Out:
# <_MapDataset element_spec={'source': TensorSpec(shape=(None, None, 20), dtype=tf.float32, name=None), 'target': TensorSpec(shape=(None, None), dtype=tf.int64, name=None)}>
# <_MapDataset element_spec={'source': TensorSpec(shape=(None, None, 20), dtype=tf.float32, name=None), 'target': TensorSpec(shape=(None, None), dtype=tf.int64, name=None)}>
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - loss: 3.4989
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (8, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# target:     <should be treated by likes",>
# prediction: <l ]Kl m[ed p%iUJH^(pCl qB<p{iUta.>
#
# target:     <In midApril Anglesey>
# prediction: <88yKl m[ed ]IhUp{YkpCl qB<p{iUta.>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <l ]Kl m[ed p%iUJH^(pCl qB<p{iUta.>
#
# target:     <beauty of the place quite>
# prediction: <88yKl m[ed p%iUp{YkpCl qB<p{iUta.>
#
# target:     <taking Clarence, who was now>
# prediction: <l ]Kl m[ed p%iUp{YkO=k!Yl{p{iUta.>
#
# target:     <this to be wondered at, for even today,>
# prediction: <88yKl m[ed ]IhUJH^(pCl qB<p{iUta.>
#
# target:     <except for them, Whitehall should>
# prediction: <l ]Kl m[ed p%iUJH^(pCl qB<p{iUta.>
#
# target:     <be deserted. It is their protest>
# prediction: <l ]Kl m[ed p%iUJH^(pCl qB<p{iUta.>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 92s 13s/step - loss: 3.4860 - val_loss: 3.2972
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 3.2367 target:     <should be treated by likes",>
# prediction: <hcafi mDfiii M toYce ]p thUtaHe Bnpe ptocMpe ]Kpe88 e?ptey[ecaHNipeBythn., e tq pptocMK9aHiip p%HzH
#
# target:     <In midApril Anglesey>
# prediction: <hcafi m[e t>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <hcafi mDfiii M toYce ]p thUtaHe Bnpe ptocMpe ]Kpe88 e?ptey[ecaHNipeByptoepte tq pptocMK9aHiip p%HzH
#
# target:     <beauty of the place quite>
# prediction: <hcafi m[e t>
#
# target:     <taking Clarence, who was now>
# prediction: <hcafi m[e t>
#
# target:     <this to be wondered at, for even today,>
# prediction: <hcafi mDfiii M toYce ]p thUtaHe Bnpe ptocMpe ]Kpe88 e?ptey[ecaHNipeByptoeEte tq pptocMK9aHiip p%HzH
#
# target:     <except for them, Whitehall should>
# prediction: <hcafi mDfiii M toYce ]p thUtaHe Bnpe ptocMpe ]Kpe88 e?ptey[ecaHNipeByptoepte tq pptocMK9aHiip p%HzH
#
# target:     <be deserted. It is their protest>
# prediction: <hcafi mDfiii M toYce ]p thUtaHe Bnpe ptocMpe ]Kpe88 e?ptey[ecaHNipeBythn., e tq pptocMK9aHiip p%HzH
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 584ms/step - loss: 3.2194 - val_loss: 2.9299
# Epoch 3/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 2.8580target:     <should be treated by likes",>
# prediction: <he t tathn toe to t af the taae ti anptoce e tape e e at the atoe ee the the th pes toe t iipe t ae
#
# target:     <In midApril Anglesey>
# prediction: <he t tathn toe to t af the taae ta anptoce e tape e e at the atoe ee the the th pes toe t ii e t ae
#
# target:     <In midapril Anglesey moved his family>
# prediction: <he t tathn toe to t af the taae ti anptoce e tape e e at the atoe ee the the th pes toe t iipe t ae
#
# target:     <beauty of the place quite>
# prediction: <he t tathn toe to t af the taae ti anptoce e tape e e at the atoe ee the the th pes toe t ii e t ae
#
# target:     <taking Clarence, who was now>
# prediction: <he an athn toe to t af the taae ti anptoce e tape e e at the atoe ee the the th pes toe t iipe t ae
#
# target:     <this to be wondered at, for even today,>
# prediction: <he t tathn toe to t af the taae ti anptoce e tape e e at the atoe ee the the th pes toe t ii e t ae
#
# target:     <except for them, Whitehall should>
# prediction: <he t tathn toe to t af the taHe ti anptoce e tape e e at the atoe ee the the th pes toe t iipe t ae
#
# target:     <be deserted. It is their protest>
# prediction: <he t tathn toe to t af the taae ti anptoce e tape e e at the atoe ee the the th pes toe t iipe t ae
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 621ms/step - loss: 2.8224 - val_loss: 2.6071
# Epoch 4/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 2.5404target:     <should be treated by likes",>
# prediction: <he t the t toe to t the the te ton an tone e anoe e e te the atoe ee the the the the e ot ii e t ae
#
# target:     <In midApril Anglesey>
# prediction: <he t the t toe to t the the te ton an tone e anoe e e atenote toe ee the the the the e ot ii e t ae
#
# target:     <In midapril Anglesey moved his family>
# prediction: <he t the t toe to t the the te ton an tone e anoe e e te the atoe ee the the the the e ot ii e t ae
#
# target:     <beauty of the place quite>
# prediction: <he t the t toe to t the the te ton an tone e anoe e e atenote toe ee the the the the e ot ii e t ae
#
# target:     <taking Clarence, who was now>
# prediction: <he t the t toe to t the the te ton an tone e anoe e e atenote toe ee the the the the e ot ii e t ae
#
# target:     <this to be wondered at, for even today,>
# prediction: <he t the t toe to t the the te ton an tone e anoe e e atenote toe ee the the the the e ot ii e t ae
#
# target:     <except for them, Whitehall should>
# prediction: <he t the t toe to t the the te ton an tone e anoe e e te the atoe ee the the the the e ot ii e t ae
#
# target:     <be deserted. It is their protest>
# prediction: <he t the t toe to t the the te ton an tone e anoe e e te the atoe ee the the the the e ot ii e t ae
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 606ms/step - loss: 2.5155 - val_loss: 2.4237
# Epoch 5/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 2.3848target:     <should be treated by likes",>
# prediction: <the t t the the o t the the t t t the to toe the te the the the he the the e the the e the t t t ae
#
# target:     <In midApril Anglesey>
# prediction: <the t t the the o t the the t t t the to toe the te the the the he the the e the the e the t t t ae
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the t t the the o t the the t t t the to toe the te the the the he the the e the the e the t t t ae
#
# target:     <beauty of the place quite>
# prediction: <the t t the the o t the the t t t the to toe the te the the the he the the e the the e the t t t ae
#
# target:     <taking Clarence, who was now>
# prediction: <the t t the the o t the the t t t the to toe the te the the the he the the e the the e the t t t ae
#
# target:     <this to be wondered at, for even today,>
# prediction: <the t t the the o t the the t t t the to toe the te the the the he the the e the the e the t t t ae
#
# target:     <except for them, Whitehall should>
# prediction: <the t t the the o t the the t t t the to toe the te the the the he the the e the the e the t t t ae
#
# target:     <be deserted. It is their protest>
# prediction: <the t t the the o t the the t t t the to toe the te the the the he the the e the the e the t t t ae
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 722ms/step - loss: 2.3667 - val_loss: 2.3401
# Epoch 6/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 2.3087target:     <should be treated by likes",>
# prediction: <the t the ar the the t he the the atonthe the the e the the the he the the e therer te the the t ae
#
# target:     <In midApril Anglesey>
# prediction: <the t the ar the the t he the the atonthe the the e the the the he the the e therer te the the t ae
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the t the ar the the t he the the atonthe the the e the the the he the the e therer te the the t ae
#
# target:     <beauty of the place quite>
# prediction: <the t the ar the the t he the the atonthe the the e the the the he the the e therer te the the t ae
#
# target:     <taking Clarence, who was now>
# prediction: <the t the ar the the t he the the atonthe the the e the the the he the the e therer te the the t ae
#
# target:     <this to be wondered at, for even today,>
# prediction: <the t the ar the the t he the the atonthe the the e the the the he the the e therer te the the t ae
#
# target:     <except for them, Whitehall should>
# prediction: <the t the ar the the t he the the atonthe the the e the the the he the the e therer te the the t ae
#
# target:     <be deserted. It is their protest>
# prediction: <the t the ar the the t he the the atonthe the the e the the the he the the e therer te the the t ae
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 712ms/step - loss: 2.2925 - val_loss: 2.2742
# Epoch 7/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 2.2385target:     <should be treated by likes",>
# prediction: <the ton the the athe the on the thes the the ans the the thend the the the thed the toure is the an
#
# target:     <In midApril Anglesey>
# prediction: <the ton the the athe the on the thes the the ans the the thend the the the thed the toure is the an
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the ton the the athe the on the thes the the ans the the thend the the the thed the toure is the an
#
# target:     <beauty of the place quite>
# prediction: <the ton the the athe the on the thes the the ans the the thend the the the thed the toure is the an
#
# target:     <taking Clarence, who was now>
# prediction: <the ton the the athe the on the thes the the ans the the thend the the the thed the toure is the an
#
# target:     <this to be wondered at, for even today,>
# prediction: <the ton the the athe the on the thes the the ans the the thend the the the thed the toure is the an
#
# target:     <except for them, Whitehall should>
# prediction: <the ton the the athe the on the thes the the ans the the thend the the the thed the toure is the an
#
# target:     <be deserted. It is their protest>
# prediction: <the ton the the athe the on the thes the the ans the the thend the the the thed the toure is the an
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 583ms/step - loss: 2.2228 - val_loss: 2.2206
# Epoch 8/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 2.1684target:     <should be treated by likes",>
# prediction: <the tond the t the the the the>
#
# target:     <In midApril Anglesey>
# prediction: <the tond the t the the the the>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the tond the t the the the the>
#
# target:     <beauty of the place quite>
# prediction: <the tond the t the the the the>
#
# target:     <taking Clarence, who was now>
# prediction: <the tond the t the the the the>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the tond the t the the the the>
#
# target:     <except for them, Whitehall should>
# prediction: <the tond the t the the the the>
#
# target:     <be deserted. It is their protest>
# prediction: <the tond the t the the the the>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 601ms/step - loss: 2.1554 - val_loss: 2.1766
# Epoch 9/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 2.1016target:     <should be treated by likes",>
# prediction: <the tond the t the an are the the an>
#
# target:     <In midApril Anglesey>
# prediction: <the tond the t the an are the the an>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the tond the t the an are the the an>
#
# target:     <beauty of the place quite>
# prediction: <the tond the t the an are the the an>
#
# target:     <taking Clarence, who was now>
# prediction: <the tond the t the an are the the an>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the tond the t the an are the the an>
#
# target:     <except for them, Whitehall should>
# prediction: <the tond the t the an are the the an>
#
# target:     <be deserted. It is their protest>
# prediction: <the tond the t the an are the the an>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 747ms/step - loss: 2.0967 - val_loss: 2.1432
# Epoch 10/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 2.0579target:     <should be treated by likes",>
# prediction: <the the the the te athe t the te the>
#
# target:     <In midApril Anglesey>
# prediction: <the the the the te athe t the te the>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the the the the te athe t the te the>
#
# target:     <beauty of the place quite>
# prediction: <the the the the te athe t the te the>
#
# target:     <taking Clarence, who was now>
# prediction: <the the the the te athe t the te the>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the the the the te athe t the te the>
#
# target:     <except for them, Whitehall should>
# prediction: <the the the the te athe t the te the>
#
# target:     <be deserted. It is their protest>
# prediction: <the the the the te athe t the te the>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 587ms/step - loss: 2.0486 - val_loss: 2.1235
# Epoch 11/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 2.0103target:     <should be treated by likes",>
# prediction: <the the the the te athe t the ted an>
#
# target:     <In midApril Anglesey>
# prediction: <the the the the te athe t the ted an>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the the the the te athe t the ted an>
#
# target:     <beauty of the place quite>
# prediction: <the the the the te athe t the ted an>
#
# target:     <taking Clarence, who was now>
# prediction: <the the the the te athe t the ted an>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the the the the te athe t the ted an>
#
# target:     <except for them, Whitehall should>
# prediction: <the the the the te athe t the ted an>
#
# target:     <be deserted. It is their protest>
# prediction: <the the the the te athe t the ted an>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 617ms/step - loss: 2.0070 - val_loss: 2.1077
# Epoch 12/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 1.9776target:     <should be treated by likes",>
# prediction: <the the the the te athers the te>
#
# target:     <In midApril Anglesey>
# prediction: <the the the the te athers the te>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the the the the te athers the te>
#
# target:     <beauty of the place quite>
# prediction: <the the the the te athers the te>
#
# target:     <taking Clarence, who was now>
# prediction: <the the the the te athers the te>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the the the the te athers the te>
#
# target:     <except for them, Whitehall should>
# prediction: <the the the the te athers the te>
#
# target:     <be deserted. It is their protest>
# prediction: <the the the the te athers the te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 639ms/step - loss: 1.9747 - val_loss: 2.1017
# Epoch 13/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 1.9535target:     <should be treated by likes",>
# prediction: <the the the the te athers the te>
#
# target:     <In midApril Anglesey>
# prediction: <the the the the te athers the te>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the the the the te athers the te>
#
# target:     <beauty of the place quite>
# prediction: <the the the the te athers the te>
#
# target:     <taking Clarence, who was now>
# prediction: <the the the the te athers the te>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the the the the te athers the te>
#
# target:     <except for them, Whitehall should>
# prediction: <the the the the te athers the te>
#
# target:     <be deserted. It is their protest>
# prediction: <the the the the te athers the te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 588ms/step - loss: 1.9477 - val_loss: 2.0948
# Epoch 14/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.9299target:     <should be treated by likes",>
# prediction: <the tome the t the athers the te>
#
# target:     <In midApril Anglesey>
# prediction: <the tome the t the athers the te>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the tome the t the athers the te>
#
# target:     <beauty of the place quite>
# prediction: <the tome the t the athers the te>
#
# target:     <taking Clarence, who was now>
# prediction: <the tome the t the athers the te>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the tome the t the athers the te>
#
# target:     <except for them, Whitehall should>
# prediction: <the tome the t the athers the te>
#
# target:     <be deserted. It is their protest>
# prediction: <the tome the t the athers the te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 691ms/step - loss: 1.9247 - val_loss: 2.0901
# Epoch 15/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.9082target:     <should be treated by likes",>
# prediction: <the tome the t the athe t the te>
#
# target:     <In midApril Anglesey>
# prediction: <the tome the t the athe t the te>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the tome the t the athe t the te>
#
# target:     <beauty of the place quite>
# prediction: <the tome the t the athe t the te>
#
# target:     <taking Clarence, who was now>
# prediction: <the tome the t the athe t the te>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the tome the t the athe t the te>
#
# target:     <except for them, Whitehall should>
# prediction: <the tome the t the athe t the te>
#
# target:     <be deserted. It is their protest>
# prediction: <the tome the t the athe t the te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 598ms/step - loss: 1.9034 - val_loss: 2.0854
# Epoch 16/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.8881target:     <should be treated by likes",>
# prediction: <the tome the t the athe t the te>
#
# target:     <In midApril Anglesey>
# prediction: <the tome the t the athe t the te>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the tome the t the athe t the te>
#
# target:     <beauty of the place quite>
# prediction: <the tome the t the athe t the te>
#
# target:     <taking Clarence, who was now>
# prediction: <the tome the t the athe t the te>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the tome the t the athe t the te>
#
# target:     <except for them, Whitehall should>
# prediction: <the tome the t the athe t the te>
#
# target:     <be deserted. It is their protest>
# prediction: <the tome the t the athe t the te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 586ms/step - loss: 1.8837 - val_loss: 2.0843
# Epoch 17/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 1.8691target:     <should be treated by likes",>
# prediction: <the tome the t the athe tonte te>
#
# target:     <In midApril Anglesey>
# prediction: <the tome the t the athere the te>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the tome the t the athe tonte te>
#
# target:     <beauty of the place quite>
# prediction: <the tome the t the athere the te>
#
# target:     <taking Clarence, who was now>
# prediction: <the tome the t the athere the te>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the tome the t the athere the te>
#
# target:     <except for them, Whitehall should>
# prediction: <the tome the t the athe tonte te>
#
# target:     <be deserted. It is their protest>
# prediction: <the tome the t the athe tonte te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 715ms/step - loss: 1.8650 - val_loss: 2.0836
# Epoch 18/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.8518target:     <should be treated by likes",>
# prediction: <the tome the e the athere the te>
#
# target:     <In midApril Anglesey>
# prediction: <the tome the t the athere the te>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the tome the e the athere the te>
#
# target:     <beauty of the place quite>
# prediction: <the tome the t the athere the te>
#
# target:     <taking Clarence, who was now>
# prediction: <the tome the t the athere the te>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the tome the t the athere the te>
#
# target:     <except for them, Whitehall should>
# prediction: <the to of fromere the the the tere>
#
# target:     <be deserted. It is their protest>
# prediction: <the tome the e the athere the te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 598ms/step - loss: 1.8479 - val_loss: 2.0825
# Epoch 19/20
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.8352target:     <should be treated by likes",>
# prediction: <the erede the tome athere the tes te>
#
# target:     <In midApril Anglesey>
# prediction: <the tome the e the athere the>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the erede the tome athere the tes te>
#
# target:     <beauty of the place quite>
# prediction: <the tome the e the athere the>
#
# target:     <taking Clarence, who was now>
# prediction: <the tome the e the athere the>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the tome the e the athere the>
#
# target:     <except for them, Whitehall should>
# prediction: <the erede the tome athe tonte te the>
#
# target:     <be deserted. It is their protest>
# prediction: <the erede the tome athere the te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 593ms/step - loss: 1.8315 - val_loss: 2.0822
# Epoch 20/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 1.8170target:     <should be treated by likes",>
# prediction: <the erede the tome athere the tes te>
#
# target:     <In midApril Anglesey>
# prediction: <the erede the tome athere the>
#
# target:     <In midapril Anglesey moved his family>
# prediction: <the erede the tome athere the tes te>
#
# target:     <beauty of the place quite>
# prediction: <the erede the tome athere the>
#
# target:     <taking Clarence, who was now>
# prediction: <the erede the tome athere the>
#
# target:     <this to be wondered at, for even today,>
# prediction: <the erede the tome athere the>
#
# target:     <except for them, Whitehall should>
# prediction: <the erede the tome athe tonte ared>
#
# target:     <be deserted. It is their protest>
# prediction: <the erede the tome athere the te>
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 721ms/step - loss: 1.8156 - val_loss: 2.0876

# %%
# Evaluate the model
test_dataset = create_tf_dataset(dev_data, batch_size=32)
idx_to_char = vectorizer.get_vocabulary()

result=[]
for batch_idx, batch in enumerate( test_dataset):
  print(batch_idx)
  source = batch["source"]
  target = batch["target"].numpy()
  bs = tf.shape(source)[0]
  preds = model.generate(source, 2)
  preds = preds.numpy()
  for i in range(bs):
      target_text = "".join([idx_to_char[_] for _ in target[i, :]])
      prediction = ""
      for idx in preds[i, :]:
          prediction += idx_to_char[idx]
          if idx == 3:
              break
      result.append({"target":target_text.replace('-',''),"prediction":prediction})
      # print(f"target:     {target_text.replace('-','')}")
      # print(f"prediction: {prediction}\n")
# Out:
# 0
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (18, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(

# %%
# Convert the result to a pandas dataframe
prediction_result = pd.DataFrame(result)
prediction_result.head()
# Out:
#                                     target  \
# 0           <should be treated by likes",>
# 1                   <In midApril Anglesey>
# 2  <In midapril Anglesey moved his family>
# 3              <beauty of the place quite>
# 4           <taking Clarence, who was now>
#
#                                prediction
# 0  <the erede the tome athere the tes te>
# 1         <the erede the tome athere the>
# 2  <the erede the tome athere the tes te>
# 3         <the erede the tome athere the>
# 4         <the erede the tome athere the>

# %%
#  Normalize the results
prediction_result['prediction'] = prediction_result['prediction'].apply(lambda x:x.replace('<','').replace('>',''))
prediction_result['target'] = prediction_result['target'].apply(lambda x:x.replace('<','').replace('>',''))

# %%
#  Calculate the accuracy of the model using character error rate (CER) and word error rate (WER)
prediction_result['wer'] = prediction_result.apply(lambda x: wer(x.target, x.prediction) , axis=1)
prediction_result['cer'] = prediction_result.apply(lambda x: cer(x.target, x.prediction) , axis=1)
print(f" cer {prediction_result['cer'].mean():.5f} wer {prediction_result['wer'].mean():.5f}")
# Out:
#  cer 0.88589 wer 1.00000

# %%
#  Write the results to a excel file
# !mkdir Results
prediction_result.to_excel('Results/iam_results_01.xlsx')

# %%
#  Save the model
model.save_weights('Models/iam80.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-d30f5e83c6a1> in <cell line: 2>()
#       1 #  Save the model
# ----> 2 model.save_weights('Models/iam80.h5')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in save_weights(model, filepath, overwrite, **kwargs)
#     215 def save_weights(model, filepath, overwrite=True, **kwargs):
#     216     if not str(filepath).endswith(".weights.h5"):
# --> 217         raise ValueError(
#     218             "The filename must end in `.weights.h5`. "
#     219             f"Received: filepath={filepath}"
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=Models/iam80.h5
